# %%
from data_tidy import read_a_season,read_all_game

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
read_a_season("../nhl_data/",2016).to_csv('./tidy_{season}.csv'.format(season=2016), sep=',')
# Out:
# 100%|███████████████████████████████████████████| 6433/6433 [00:27<00:00, 236.83it/s]

# %%
result = pd.DataFrame()
for i in [2018,2019,2020]:
    temp = read_a_season("../nhl_data/",i)
    result = pd.concat([result,temp],ignore_index=True)
result.to_csv('./tidy_{season}.csv'.format(season="2018-2020"), sep=',')
# Out:
# ...
# 100%|███████████████████████████████████████████| 6433/6433 [00:16<00:00, 392.03it/s]

# %%
season_2016_path = "./tidy_2016.csv"
season_20182020_path = "./tidy_20182020.csv"

# %%
df_2016 = pd.read_csv(season_2016_path).reset_index()
df_2016
# Out:
#        index  Unnamed: 0     game_id  event_idx play_type   shot_type  \
# 0          0           0  2016020594          5      Shot  Wrist Shot
# 1          1           1  2016020594          6      Goal  Wrist Shot
# 2          2           2  2016020594         14      Shot      Tip-In
# 3          3           3  2016020594         16      Shot  Wrist Shot
# 4          4           4  2016020594         17      Shot  Wrist Shot
# ...      ...         ...         ...        ...       ...         ...
# 80394  80394       80394  2016020295        253      Goal  Wrist Shot
# 80395  80395       80395  2016020295        255      Shot  Wrist Shot
# 80396  80396       80396  2016020295        272      Shot   Snap Shot
# 80397  80397       80397  2016020295        282      Goal    Backhand
# 80398  80398       80398  2016020295        287      Goal  Wrist Shot
#
#        shot_dist             game_time            team_home  \
# 0      57.775427  2017-01-08T00:00:00Z  Toronto Maple Leafs
# ...

# %%
df_2016_shots = df_2016.groupby(["attack_team_name","shot_type"]).agg("count").reset_index()
df_2016_shots = df_2016_shots.pivot(index = "attack_team_name",columns = "shot_type", values = "index")
df_2016_shots.groupby()
# Out:
# shot_type              Backhand  Deflected  Slap Shot  Snap Shot  Tip-In  \
# attack_team_name
# Anaheim Ducks               216         19        565        336     251
# Arizona Coyotes             186          9        339        166     111
# Boston Bruins               229         34        458        583     135
# Buffalo Sabres              227         34        378        360     119
# Calgary Flames              211         17        389        250     159
# Carolina Hurricanes         203         41        411        675     106
# Chicago Blackhawks          210         18        650        239      92
# Colorado Avalanche          173         22        437        254      93
# Columbus Blue Jackets       273         25        353        696     107
# Dallas Stars                228         33        350        314     134
# Detroit Red Wings           248         38        386        371     109
# Edmonton Oilers             292         24        417        632     183
# ...

# %%
df_goals = df[df["play_type"]=="Goal"]
df_goals_1 = df_goals.groupby(["attack_team_name","shot_type"]).agg("count").reset_index()
df_goals_2 = df_goals_1.pivot(index="attack_team_name",columns = "shot_type", values = "index").fillna(0).astype(int)
df_goals_2["total"] = df_goals_2.sum(axis=1)
df_goals_2
# Out:
# shot_type              Backhand  Deflected  Slap Shot  Snap Shot  Tip-In  \
# attack_team_name
# Anaheim Ducks                21          1         40         37      37
# Arizona Coyotes              22          1         13         21      21
# Boston Bruins                25          8         33         56      17
# Buffalo Sabres               28          9         19         26      19
# Calgary Flames               27          3         27         15      29
# Carolina Hurricanes          19         11         23         61       8
# Chicago Blackhawks           25          2         43         27      11
# Colorado Avalanche           11          4         22         19      24
# Columbus Blue Jackets        27          6         16         76      24
# Dallas Stars                 20          6         16         23      23
# Detroit Red Wings            28          9         21         46      10
# Edmonton Oilers              31          7         26         47      29
# ...

# %%
# pd.set_option('display.max_rows', 100)
df1 = df.groupby(["attack_team_name","shot_type"]).agg("count").reset_index()

df2 = df1.pivot(index="attack_team_name",columns = "shot_type",values = "game_id")
df2["total"] = df2.sum(axis=1)
df2
# Out:
# shot_type              Backhand  Deflected  Slap Shot  Snap Shot  Tip-In  \
# attack_team_name
# Anaheim Ducks               216         19        565        336     251
# Arizona Coyotes             186          9        339        166     111
# Boston Bruins               229         34        458        583     135
# Buffalo Sabres              227         34        378        360     119
# Calgary Flames              211         17        389        250     159
# Carolina Hurricanes         203         41        411        675     106
# Chicago Blackhawks          210         18        650        239      92
# Colorado Avalanche          173         22        437        254      93
# Columbus Blue Jackets       273         25        353        696     107
# Dallas Stars                228         33        350        314     134
# Detroit Red Wings           248         38        386        371     109
# Edmonton Oilers             292         24        417        632     183
# ...

# %%
df_goals_2.div(df2)
# Out:
# shot_type              Backhand  Deflected  Slap Shot  Snap Shot    Tip-In  \
# attack_team_name
# Anaheim Ducks          0.097222   0.052632   0.070796   0.110119  0.147410
# Arizona Coyotes        0.118280   0.111111   0.038348   0.126506  0.189189
# Boston Bruins          0.109170   0.235294   0.072052   0.096055  0.125926
# Buffalo Sabres         0.123348   0.264706   0.050265   0.072222  0.159664
# Calgary Flames         0.127962   0.176471   0.069409   0.060000  0.182390
# Carolina Hurricanes    0.093596   0.268293   0.055961   0.090370  0.075472
# Chicago Blackhawks     0.119048   0.111111   0.066154   0.112971  0.119565
# Colorado Avalanche     0.063584   0.181818   0.050343   0.074803  0.258065
# Columbus Blue Jackets  0.098901   0.240000   0.045326   0.109195  0.224299
# Dallas Stars           0.087719   0.181818   0.045714   0.073248  0.171642
# Detroit Red Wings      0.112903   0.236842   0.054404   0.123989  0.091743
# ...

# %%
a = np.array([10,10])
b = np.array([1,10])
np.linalg.norm(b-a)
# Out:
# 9.0
